# %% [markdown]
# ![image.png](attachment:image.png)
#
# <img width="1916" height="991" alt="image" src="https://github.com/user-attachments/assets/07f332ea-451e-48c4-86eb-acfd95df3a8f" />
#
# #### True Color Image
#
# The Red, Green, and Blue bands are combined in such a way as to replicate what a photographic camera would see
